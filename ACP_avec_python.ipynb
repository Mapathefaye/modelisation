# %% [markdown]
# Les Packages utiles

# %%
import pandas as pd  # pour importer les data
import numpy as np
import matplotlib as mp
from sklearn import preprocessing
from sklearn import preprocessing

# %% [markdown]
# # Chager les données sur les performances d'athlètes olympques
#  Ce jeu de données contient 41 entrées, qui décrivent chacune les performances d'un athlète à une compétition de décathlon.
#  Nous allons faire une ACP des dix variables décrivant les performances à chacune des épreuves du décathlon
#  (100 mètres, saut en longueur, lancer de poids, saut en hauteur, 400 mètres, 110 mètres haies, lancer de disque, saut à la perche, javelot et 1 500 mètres)

# %%
data = pd.read_csv('decathlon.txt', sep= '\t')
data.head()
# Out:
#           100m  Long.jump  Shot.put  High.jump   400m  110m.hurdle  Discus  \
# SEBRLE   11.04       7.58     14.83       2.07  49.81        14.69   43.75
# CLAY     10.76       7.40     14.26       1.86  49.37        14.05   50.72
# KARPOV   11.02       7.30     14.77       2.04  48.37        14.09   48.95
# BERNARD  11.02       7.23     14.25       1.92  48.93        14.99   40.87
# YURKOV   11.34       7.09     15.19       2.10  50.42        15.31   46.26
#
#          Pole.vault  Javeline  1500m  Rank  Points Competition
# SEBRLE         5.02     63.19  291.7     1    8217    Decastar
# CLAY           4.92     60.15  301.5     2    8122    Decastar
# KARPOV         4.92     50.31  300.2     3    8099    Decastar
# BERNARD        5.32     62.77  280.1     4    8067    Decastar
# YURKOV         4.72     63.44  276.4     5    8036    Decastar

# %% [markdown]
# Enlevons les colonnes qui ne correspondent pas à des performanc

# %%
my_data = data.drop(['Rank', 'Points', 'Competition'], axis=1)

# %% [markdown]
# Convertir les data en un array numpy que je vais appeler X

# %%
X = my_data.values
X.shape
# Out:
# (41, 10)

# %% [markdown]
# Nous avons fait l'hypothèse que les données étaient centrées. Nous allons donc commencer par les standardiser.
# Pour cela on utilise sklearn avec sa classe preprocessing

# %%
std_scale = preprocessing.StandardScaler().fit(X)
X_scaled = std_scale.transform(X)

# %% [markdown]
# Je peux maintenant faire mon ACP tjrs en utilisant sklearn avec sa classe decomposition
# Calculons maintenant les deux premières composantes principales

# %%
from sklearn import decomposition
pca = decomposition.PCA(n_components=2)
pca.fit(X_scaled)
# Out:
# PCA(n_components=2)

# %% [markdown]
# Maintenant on avoir le pourcentage de variance expliquée par chacune des composantes comme suit:
# La première composante explique environ un tiers de la variance observée dans les données,
#     et la deuxième 17,3 %. Au total, ces deux composantes expliquent 50 % de la variance totale,
#     en utilisant seulement un cinquième des dimensions initiales.

# %%
print(pca.explained_variance_ratio_)
print(pca.explained_variance_ratio_.cumsum())  # pourcentage cumulé
# Out:
# [0.32719055 0.1737131 ]
# [0.32719055 0.50090366]

# %% [markdown]
# Représenter chaque athlète/compétition selon ces deux dimensions uniquement,
# et colorer chacun des points correspondants en fonction du classement de l'athlète lors de cette compétition.

# %%
import matplotlib.pyplot as plt


# projeter X sur les composantes principales
X_projected = pca.transform(X_scaled)

# afficher chaque observation
plt.scatter(X_projected[:, 0], X_projected[:, 1],
    # colorer en utilisant la variable 'Rank'
    c=data.Rank)

plt.xlim([-5.5, 5.5])
plt.ylim([-4, 4])
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 8
#       5 X_projected = pca.transform(X_scaled)
#       7 # afficher chaque observation
# ----> 8 plt.scatter(X_projected[:, 0], X_projected[:, 1],
#       9     # colorer en utilisant la variable 'Rank'
#      10     c=data.Rank)
#      12 plt.xlim([-5.5, 5.5])
#      13 plt.ylim([-4, 4])
#
# File c:\Program Files\Python312\Lib\site-packages\matplotlib\pyplot.py:3699, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3680 @_copy_docstring_and_deprecators(Axes.scatter)
#    3681 def scatter(
#    3682     x: float | ArrayLike,
#    (...)
#    3697     **kwargs,
#    3698 ) -> PathCollection:
# -> 3699     __ret = gca().scatter(
#    3700         x,
#    3701         y,
#    3702         s=s,
#    3703         c=c,
#    3704         marker=marker,
#    3705         cmap=cmap,
#    3706         norm=norm,
#    3707         vmin=vmin,
#    3708         vmax=vmax,
#    3709         alpha=alpha,
#    3710         linewidths=linewidths,
#    3711         edgecolors=edgecolors,
#    3712         plotnonfinite=plotnonfinite,
#    3713         **({"data": data} if data is not None else {}),
#    3714         **kwargs,
#    3715     )
#    3716     sci(__ret)
#    3717     return __ret
#
# File c:\Program Files\Python312\Lib\site-packages\matplotlib\pyplot.py:2540, in gca()
#    2538 @_copy_docstring_and_deprecators(Figure.gca)
#    2539 def gca() -> Axes:
# -> 2540     return gcf().gca()
#
# File c:\Program Files\Python312\Lib\site-packages\matplotlib\pyplot.py:1000, in gcf()
#     998     return manager.canvas.figure
#     999 else:
# -> 1000     return figure()
#
# File c:\Program Files\Python312\Lib\site-packages\matplotlib\pyplot.py:934, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     924 if len(allnums) == max_open_warning >= 1:
#     925     _api.warn_external(
#     926         f"More than {max_open_warning} figures have been opened. "
#     927         f"Figures created through the pyplot interface "
#    (...)
#     931         f"Consider using `matplotlib.pyplot.close()`.",
#     932         RuntimeWarning)
# --> 934 manager = new_figure_manager(
#     935     num, figsize=figsize, dpi=dpi,
#     936     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#     937     FigureClass=FigureClass, **kwargs)
#     938 fig = manager.canvas.figure
#     939 if fig_label:
#
# File c:\Program Files\Python312\Lib\site-packages\matplotlib\pyplot.py:464, in new_figure_manager(*args, **kwargs)
#     462 def new_figure_manager(*args, **kwargs):
#     463     """Create a new figure manager instance."""
# --> 464     _warn_if_gui_out_of_main_thread()
#     465     return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File c:\Program Files\Python312\Lib\site-packages\matplotlib\pyplot.py:441, in _warn_if_gui_out_of_main_thread()
#     439 def _warn_if_gui_out_of_main_thread() -> None:
#     440     warn = False
# --> 441     canvas_class = cast(type[FigureCanvasBase], _get_backend_mod().FigureCanvas)
#     442     if canvas_class.required_interactive_framework:
#     443         if hasattr(threading, 'get_native_id'):
#     444             # This compares native thread ids because even if Python-level
#     445             # Thread objects match, the underlying OS thread (which is what
#     446             # really matters) may be different on Python implementations with
#     447             # green threads.
#
# File c:\Program Files\Python312\Lib\site-packages\matplotlib\pyplot.py:280, in _get_backend_mod()
#     271 """
#     272 Ensure that a backend is selected and return it.
#     273
#     274 This is currently private, but may be made public in the future.
#     275 """
#     276 if _backend_mod is None:
#     277     # Use rcParams._get("backend") to avoid going through the fallback
#     278     # logic (which will (re)import pyplot and then call switch_backend if
#     279     # we need to resolve the auto sentinel)
# --> 280     switch_backend(rcParams._get("backend"))  # type: ignore[attr-defined]
#     281 return cast(type[matplotlib.backend_bases._Backend], _backend_mod)
#
# File c:\Program Files\Python312\Lib\site-packages\matplotlib\pyplot.py:342, in switch_backend(newbackend)
#     339 # have to escape the switch on access logic
#     340 old_backend = dict.__getitem__(rcParams, 'backend')
# --> 342 module = importlib.import_module(cbook._backend_module_name(newbackend))
#     343 canvas_class = module.FigureCanvas
#     345 required_framework = canvas_class.required_interactive_framework
#
# File c:\Program Files\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1310, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'matplotlib_inline'
